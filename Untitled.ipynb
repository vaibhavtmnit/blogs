# %%
import pandas as pd
import numpy as np

# %%
x = np.arange(-5,5,.1)
y1 = x**2
y2 = x**4
y3 = x**8

# %%
df = pd.DataFrame({'x_sqaure':y1,
                  'x_power_four':y2,
                  'x_power_eight':y3})

# %%
df.plot(xlim=[0,100],ylim=[-1,50])
# Out:
# <AxesSubplot:>
